# %% [markdown]
# Tihar Sales Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df=pd.read_csv(r"C:\Users\USER\Downloads\Diwali Sales Data.csv",encoding='unicode_escape')
df.shape
# Out:
# (11251, 15)

# %%
df.head()
df.info()

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#drop null vlaues
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# Gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sns.countplot(x='Gender',data=df)
ax=sns.countplot(x='Gender',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen, palette='Set1')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_29132\1320306954.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender',y='Amount',data=sales_gen, palette='Set1')

# %%
# Count plot with Age Group and Gender differentiation
ax = sns.countplot(x='Age Group', data=df, hue='Gender')  # Add hue for Gender
for bars in ax.containers:
    ax.bar_label(bars)

# Group by Age Group and Gender to show Amount distribution
sales_age_gender = df.groupby(['Age Group', 'Gender'], as_index=False)['Amount'].sum()

# Bar plot with Age Group, Amount, and Gender differentiation
sns.barplot(x='Age Group', y='Amount', hue='Gender', data=sales_age_gender)  # Add hue for Gender

plt.show()
